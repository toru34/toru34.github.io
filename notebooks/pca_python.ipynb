# %%
# %matplotlib inline

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../datasets/glove.6B/glove.6B.50d.txt', sep=' ', index_col=0, header=None, quoting=3)

# %%
n_components = 2

words = ['japan', 'tokyo', 'china', 'beijing', 'france', 'paris', 'germany', 'berlin']

X = df.loc[words, :].to_numpy()
cov_X = np.cov(X, rowvar=False)

eig_vals, eig_vecs = np.linalg.eigh(cov_X)
eig_vecs = eig_vecs[:, ::-1] # Sort eigen vectors w.r.t eigen values (descending order)

P = eig_vecs[:, :n_components] # Principal components

Y = X @ P

# %%
ax = plt.subplott.subplot()

for x, y in Y:
    ax.scatter(x, y)
    ax.text(x, y, )
    break
